# %%
import pandas as pd
import numpy as np
import sklearn
import torch
print("all is working!")

# %%
print("hello")
# Out:
# Jupyter cannot be started. Error attempting to locate Jupyter: Running cells with '.venv (Python 3.12.0)' requires the notebook and jupyter package.
#
# Install 'jupyter and notebook' into the Python environment.
#
# Command: 'python -m pip install jupyter notebook -U
#
# or
#
# conda install jupyter notebook -U'
#
# Click <a href='https://aka.ms/installJupyterForVSCode'>here</a> for more info.

# %%
pip install jupyter ipykernel
# Out:
# Failed to start the Kernel.
#
# error: failed-wheel-build-for-install
#
#
#
# × Failed to build installable wheels for some pyproject.toml based projects
#
# ╰─> pyzmq.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
